# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#loading the data file 
data_file = "Output/fileOne.csv"
city_data = pd.read_csv(data_file)

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Store latitude and longitude in locations
locations = city_data[["Lat", "Lng"]]

# Fill NaN values and convert to float
Humidity = city_data["Humidity"].astype(float)

# %%
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=Humidity, 
                                 dissipating=False, max_intensity=300,
                                 point_radius=5)
#plot the figure on gmaps
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#dropping rows based on tepmerature and storing data in vacation dataframe
vacation_df = city_data.loc[(city_data["Max Temp"] <= 300) & (city_data["Max Temp"] >= 295)
                            & (city_data["Cloudiness"] <= 50), :]

# %%
#dropping null values
vacation_df =vacation_df.dropna()
vacation_df
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 4         Hambantota          20      LK  1584232885       100   6.12   81.12
# 8    Bambous Virieux          40      MU  1584232684        88 -20.34   57.76
# 11           Rikitea           0      PF  1584232677        78 -23.12 -134.97
# 12            Ixtapa           5      MX  1584232972        74  20.70 -105.20
# 28          Souillac          40      MU  1584232931        88 -20.52   57.52
# 31          Filingué           0      NE  1584233265        13  14.35    3.32
# 56   Arraial do Cabo          40      BR  1584232775        94 -22.97  -42.03
# 59          Tessalit          49      ML  1584232655        12  20.20    1.01
# 63     Bambanglipuro           3      ID  1584233268        85  -7.95  110.28
# 90    Cabo San Lucas          40      MX  1584233271        50  22.89 -109.91
# 91              Chui          43      UY  1584232768        92 -33.70  -53.46
# 96             Avera           1      US  1584233271        55  33.19  -82.53
# 105           Touros          17      BR  1584232976        94  -5.20  -35.46
# 118           Yārāda          20      IN  1584233274       100  17.65   83.27
# 122           Camopi          23      GF  1584233274        72   3.17  -52.32
# 138       Itapirapuã          26      BR  1584233276        93 -15.82  -50.61
# 153          Atambua           0      ID  1584233278        78  -9.11  124.89
# 160         Yamethin          17      MM  1584233278        36  20.43   96.15
# 205   Cap Malheureux          40      MU  1584233284        88 -19.98   57.61
# 219       São Filipe          11      CV  1584233285        56  14.90  -24.50
# 242        Kabanjahe          20      ID  1584233287       100   3.10   98.49
# 250            Airai           9      TL  1584232742        54  -8.93  125.41
# 263        Mahébourg          40      MU  1584232912        88 -20.41   57.70
# 264        Mahajanga          40      MG  1584233290        94 -15.72   46.32
# 285        Road Town          40      VG  1584233292        74  18.42  -64.62
# 288          Durango          20      MX  1584233166        17  24.83 -104.83
# 317           Talara          12      PE  1584233296        79  -4.58  -81.27
# 320           Bissau           0      GW  1584232790        61  11.86  -15.60
# 321          Gamarra          34      CO  1584233296        65   8.32  -73.74
# 338          Houston          40      US  1584233083        88  29.76  -95.36
# 339     Saint-Pierre          32      RE  1584232758        78 -21.34   55.48
# 351      Grand Gaube          40      MU  1584232784        88 -20.01   57.66
# 369        Geraldton          40      AU  1584232608        78 -28.77  114.60
# 403          Sombrio           0      BR  1584233305        91 -29.11  -49.62
# 407            Dalby           0      AU  1584233306        56 -27.18  151.27
# 421    Cockburn Town           0      TC  1584233203        78  21.46  -71.14
# 425       Vila Velha          20      BR  1584233308        88 -20.33  -40.29
# 430         Cidreira           0      BR  1584232712        86 -30.18  -50.21
# 436          Griffin           1      US  1584233309        77  33.25  -84.26
# 438         Yaguajay           0      CU  1584233309        79  22.33  -79.24
# 461           Dovers          40      VC  1584233311        83  12.88  -61.18
# 468              Gao           0      ML  1584233312        11  16.64    1.64
# 471            Ndélé          20      CF  1584233313        12   8.41   20.65
# 473          Polillo          22      PH  1584233313        70  14.71  121.94
# 474          Hiriyūr           0      IN  1584233313        40  13.95   76.62
# 476     Saint-Joseph          43      RE  1584232876        78 -21.37   55.62
# 482           Najrān          40      SA  1584233314        31  17.49   44.13
# 494  Puerto Colombia          40      CO  1584233089        83  10.99  -74.95
# 496            Praia          17      CV  1584233315        50  14.92  -23.51
# 508           Dingle          27      PH  1584233316        76  11.00  122.67
# 519       Saint-Paul          40      RE  1584233317        83 -21.01   55.27
# 524          Caborca          26      MX  1584233318        40  30.58 -111.10
# 530            Beira           0      MZ  1584233319        70 -19.84   34.84
# 536          La Cruz          43      MX  1584233320        44  23.92 -106.90
# 553     Quatre Cocos          40      MU  1584233321        88 -20.21   57.76
# 555            Birao           6      CF  1584232780        17  10.28   22.79
# 558            Houma          40      US  1584233322        88  29.60  -90.72
# 559        Ascension           1      US  1584233193        65  30.22  -90.90
# 568            Dawei          41      MM  1584233323        69  14.08   98.20
# 580          Palauig          36      PH  1584233325        65  15.44  119.90
#
#      Max Temp  Wind Speed
# 4      296.15        2.60
# 8      298.15        1.00
# 11     298.85        5.42
# 12     299.15        4.60
# 28     298.15        1.00
# 31     297.73        4.68
# 56     297.15        1.50
# 59     296.87        5.30
# 63     298.86        1.27
# 90     297.15        5.10
# 91     295.30        2.22
# 96     297.15        2.10
# 105    298.15        2.10
# 118    295.15        1.00
# 122    298.83        2.79
# 138    295.64        0.62
# 153    299.60        0.48
# 160    295.60        1.89
# 205    298.15        1.00
# 219    296.44        6.74
# 242    298.15        1.49
# 250    298.01        0.76
# 263    298.15        1.00
# 264    299.15        5.14
# 285    299.15        3.60
# 288    298.25        6.46
# 317    298.82        1.80
# 320    299.15        1.50
# 321    296.04        2.31
# 338    298.15        2.10
# 339    298.15        2.10
# 351    298.15        1.00
# 369    298.15        6.20
# 403    295.17        1.39
# 407    296.15        6.70
# 421    297.80        8.99
# 425    298.15        2.10
# 430    297.71       10.96
# 436    298.15        2.05
# 438    297.87        8.40
# 461    297.15        4.10
# 468    297.94        4.62
# 471    298.35        1.45
# 473    299.99        3.61
# 474    295.05        2.88
# 476    298.15        2.10
# 482    299.15        0.24
# 494    299.15        8.20
# 496    297.15        5.70
# 508    298.31        3.69
# 519    297.15        4.10
# 524    297.04        1.34
# 530    299.87        1.50
# 536    298.43        7.83
# 553    298.15        1.00
# 555    296.94        4.02
# 558    297.59        1.50
# 559    298.15        2.60
# 568    299.70        2.39
# 580    299.01        0.60

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = vacation_df
#adding column for hotel name 
hotel_df["Hotel Name"] = ""

# %%
#using iterrows to iterate through hotels_df dataframe
for index, row in hotel_df.iterrows():
    
    rowlat = row["Lat"]
    rowlng = row["Lng"]
    location = str(rowlat)+","+ str(rowlng)
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {"location": {location},"radius":5000 ,"type": "hotel","key": g_key}
    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {location}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
            print(f"Closest hotel is {results[0]['name']}.")
            #storing results in Hotel column in df
            hotel_df.loc[index, 'Hotel Name'] = response['results'][0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        print("------------")
# Out:
# Retrieving Results for Index 4: 6.12,81.12.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 8: -20.34,57.76.
# Closest hotel is Vieux Grand Port.
# Retrieving Results for Index 11: -23.12,-134.97.
# Closest hotel is Rikitea.
# Retrieving Results for Index 12: 20.7,-105.2.
# Closest hotel is Puerto Vallarta.
# Retrieving Results for Index 28: -20.52,57.52.
# Closest hotel is Souillac.
# Retrieving Results for Index 31: 14.35,3.32.
# Closest hotel is Filingué.
# Retrieving Results for Index 56: -22.97,-42.03.
# Closest hotel is Cabo Frio.
# Retrieving Results for Index 59: 20.2,1.01.
# Closest hotel is Achemelmel.
# Retrieving Results for Index 63: -7.95,110.28.
# Closest hotel is Bantul.
# Retrieving Results for Index 90: 22.89,-109.91.
# Closest hotel is Cabo San Lucas.
# Retrieving Results for Index 91: -33.7,-53.46.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 96: 33.19,-82.53.
# Closest hotel is Avera.
# Retrieving Results for Index 105: -5.2,-35.46.
# Closest hotel is Touros.
# Retrieving Results for Index 118: 17.65,83.27.
# Closest hotel is Visakhapatnam.
# Retrieving Results for Index 122: 3.17,-52.32.
# Closest hotel is Camopi.
# Retrieving Results for Index 138: -15.82,-50.61.
# Closest hotel is Itapirapuã.
# Retrieving Results for Index 153: -9.11,124.89.
# Closest hotel is Atambua.
# Retrieving Results for Index 160: 20.43,96.15.
# Closest hotel is Yamethin.
# Retrieving Results for Index 205: -19.98,57.61.
# Closest hotel is Grand Baie.
# Retrieving Results for Index 219: 14.9,-24.5.
# Closest hotel is Sao Filipe.
# Retrieving Results for Index 242: 3.1,98.49.
# Closest hotel is Kabanjahe.
# Retrieving Results for Index 250: -8.93,125.41.
# Closest hotel is Atsabe.
# Retrieving Results for Index 263: -20.41,57.7.
# Closest hotel is Mahebourg.
# Retrieving Results for Index 264: -15.72,46.32.
# Closest hotel is Mahajanga.
# Retrieving Results for Index 285: 18.42,-64.62.
# Closest hotel is Road Town.
# Retrieving Results for Index 288: 24.83,-104.83.
# Closest hotel is Fuente del Llano.
# Retrieving Results for Index 317: -4.58,-81.27.
# Closest hotel is Talara.
# Retrieving Results for Index 320: 11.86,-15.6.
# Closest hotel is Bissau.
# Retrieving Results for Index 321: 8.32,-73.74.
# Closest hotel is Gamarra, Cesar.
# Retrieving Results for Index 338: 29.76,-95.36.
# Closest hotel is Houston.
# Retrieving Results for Index 339: -21.34,55.48.
# Closest hotel is Saint Pierre.
# Retrieving Results for Index 351: -20.01,57.66.
# Closest hotel is Goodlands.
# Retrieving Results for Index 369: -28.77,114.6.
# Closest hotel is Geraldton.
# Retrieving Results for Index 403: -29.11,-49.62.
# Closest hotel is Sombrio.
# Retrieving Results for Index 407: -27.18,151.27.
# Closest hotel is Dalby.
# Retrieving Results for Index 421: 21.46,-71.14.
# Closest hotel is Cockburn Town.
# Retrieving Results for Index 425: -20.33,-40.29.
# Closest hotel is Vila Velha.
# Retrieving Results for Index 430: -30.18,-50.21.
# Closest hotel is CIDREIRA.
# Retrieving Results for Index 436: 33.25,-84.26.
# Closest hotel is Griffin.
# Retrieving Results for Index 438: 22.33,-79.24.
# Closest hotel is Yaguajay.
# Retrieving Results for Index 461: 12.88,-61.18.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 468: 16.64,1.64.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 471: 8.41,20.65.
# Closest hotel is N'Délé.
# Retrieving Results for Index 473: 14.71,121.94.
# Closest hotel is Polillo.
# Retrieving Results for Index 474: 13.95,76.62.
# Closest hotel is Hiriyur.
# Retrieving Results for Index 476: -21.37,55.62.
# Closest hotel is Saint-Joseph.
# Retrieving Results for Index 482: 17.49,44.13.
# Closest hotel is Najran.
# Retrieving Results for Index 494: 10.99,-74.95.
# Closest hotel is Sabanilla Montecarmelo.
# Retrieving Results for Index 496: 14.92,-23.51.
# Closest hotel is Praia.
# Retrieving Results for Index 508: 11.0,122.67.
# Closest hotel is Pototan.
# Retrieving Results for Index 519: -21.01,55.27.
# Closest hotel is Saint-Paul.
# Retrieving Results for Index 524: 30.58,-111.1.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 530: -19.84,34.84.
# Closest hotel is Beira.
# Retrieving Results for Index 536: 23.92,-106.9.
# Closest hotel is La Cruz.
# Retrieving Results for Index 553: -20.21,57.76.
# Closest hotel is Central Flacq.
# Retrieving Results for Index 555: 10.28,22.79.
# Closest hotel is Birao.
# Retrieving Results for Index 558: 29.6,-90.72.
# Closest hotel is Houma.
# Retrieving Results for Index 559: 30.22,-90.9.
# Closest hotel is Gonzales.
# Retrieving Results for Index 568: 14.08,98.2.
# Closest hotel is Dawei.
# Retrieving Results for Index 580: 15.44,119.9.
# Closest hotel is Palauig.

# %%
#printing df with hotels
hotel_df
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 4         Hambantota          20      LK  1584232885       100   6.12   81.12
# 8    Bambous Virieux          40      MU  1584232684        88 -20.34   57.76
# 11           Rikitea           0      PF  1584232677        78 -23.12 -134.97
# 12            Ixtapa           5      MX  1584232972        74  20.70 -105.20
# 28          Souillac          40      MU  1584232931        88 -20.52   57.52
# 31          Filingué           0      NE  1584233265        13  14.35    3.32
# 56   Arraial do Cabo          40      BR  1584232775        94 -22.97  -42.03
# 59          Tessalit          49      ML  1584232655        12  20.20    1.01
# 63     Bambanglipuro           3      ID  1584233268        85  -7.95  110.28
# 90    Cabo San Lucas          40      MX  1584233271        50  22.89 -109.91
# 91              Chui          43      UY  1584232768        92 -33.70  -53.46
# 96             Avera           1      US  1584233271        55  33.19  -82.53
# 105           Touros          17      BR  1584232976        94  -5.20  -35.46
# 118           Yārāda          20      IN  1584233274       100  17.65   83.27
# 122           Camopi          23      GF  1584233274        72   3.17  -52.32
# 138       Itapirapuã          26      BR  1584233276        93 -15.82  -50.61
# 153          Atambua           0      ID  1584233278        78  -9.11  124.89
# 160         Yamethin          17      MM  1584233278        36  20.43   96.15
# 205   Cap Malheureux          40      MU  1584233284        88 -19.98   57.61
# 219       São Filipe          11      CV  1584233285        56  14.90  -24.50
# 242        Kabanjahe          20      ID  1584233287       100   3.10   98.49
# 250            Airai           9      TL  1584232742        54  -8.93  125.41
# 263        Mahébourg          40      MU  1584232912        88 -20.41   57.70
# 264        Mahajanga          40      MG  1584233290        94 -15.72   46.32
# 285        Road Town          40      VG  1584233292        74  18.42  -64.62
# 288          Durango          20      MX  1584233166        17  24.83 -104.83
# 317           Talara          12      PE  1584233296        79  -4.58  -81.27
# 320           Bissau           0      GW  1584232790        61  11.86  -15.60
# 321          Gamarra          34      CO  1584233296        65   8.32  -73.74
# 338          Houston          40      US  1584233083        88  29.76  -95.36
# 339     Saint-Pierre          32      RE  1584232758        78 -21.34   55.48
# 351      Grand Gaube          40      MU  1584232784        88 -20.01   57.66
# 369        Geraldton          40      AU  1584232608        78 -28.77  114.60
# 403          Sombrio           0      BR  1584233305        91 -29.11  -49.62
# 407            Dalby           0      AU  1584233306        56 -27.18  151.27
# 421    Cockburn Town           0      TC  1584233203        78  21.46  -71.14
# 425       Vila Velha          20      BR  1584233308        88 -20.33  -40.29
# 430         Cidreira           0      BR  1584232712        86 -30.18  -50.21
# 436          Griffin           1      US  1584233309        77  33.25  -84.26
# 438         Yaguajay           0      CU  1584233309        79  22.33  -79.24
# 461           Dovers          40      VC  1584233311        83  12.88  -61.18
# 468              Gao           0      ML  1584233312        11  16.64    1.64
# 471            Ndélé          20      CF  1584233313        12   8.41   20.65
# 473          Polillo          22      PH  1584233313        70  14.71  121.94
# 474          Hiriyūr           0      IN  1584233313        40  13.95   76.62
# 476     Saint-Joseph          43      RE  1584232876        78 -21.37   55.62
# 482           Najrān          40      SA  1584233314        31  17.49   44.13
# 494  Puerto Colombia          40      CO  1584233089        83  10.99  -74.95
# 496            Praia          17      CV  1584233315        50  14.92  -23.51
# 508           Dingle          27      PH  1584233316        76  11.00  122.67
# 519       Saint-Paul          40      RE  1584233317        83 -21.01   55.27
# 524          Caborca          26      MX  1584233318        40  30.58 -111.10
# 530            Beira           0      MZ  1584233319        70 -19.84   34.84
# 536          La Cruz          43      MX  1584233320        44  23.92 -106.90
# 553     Quatre Cocos          40      MU  1584233321        88 -20.21   57.76
# 555            Birao           6      CF  1584232780        17  10.28   22.79
# 558            Houma          40      US  1584233322        88  29.60  -90.72
# 559        Ascension           1      US  1584233193        65  30.22  -90.90
# 568            Dawei          41      MM  1584233323        69  14.08   98.20
# 580          Palauig          36      PH  1584233325        65  15.44  119.90
#
#      Max Temp  Wind Speed              Hotel Name
# 4      296.15        2.60
# 8      298.15        1.00        Vieux Grand Port
# 11     298.85        5.42                 Rikitea
# 12     299.15        4.60         Puerto Vallarta
# 28     298.15        1.00                Souillac
# 31     297.73        4.68                Filingué
# 56     297.15        1.50               Cabo Frio
# 59     296.87        5.30              Achemelmel
# 63     298.86        1.27                  Bantul
# 90     297.15        5.10          Cabo San Lucas
# 91     295.30        2.22
# 96     297.15        2.10                   Avera
# 105    298.15        2.10                  Touros
# 118    295.15        1.00           Visakhapatnam
# 122    298.83        2.79                  Camopi
# 138    295.64        0.62              Itapirapuã
# 153    299.60        0.48                 Atambua
# 160    295.60        1.89                Yamethin
# 205    298.15        1.00              Grand Baie
# 219    296.44        6.74              Sao Filipe
# 242    298.15        1.49               Kabanjahe
# 250    298.01        0.76                  Atsabe
# 263    298.15        1.00               Mahebourg
# 264    299.15        5.14               Mahajanga
# 285    299.15        3.60               Road Town
# 288    298.25        6.46        Fuente del Llano
# 317    298.82        1.80                  Talara
# 320    299.15        1.50                  Bissau
# 321    296.04        2.31          Gamarra, Cesar
# 338    298.15        2.10                 Houston
# 339    298.15        2.10            Saint Pierre
# 351    298.15        1.00               Goodlands
# 369    298.15        6.20               Geraldton
# 403    295.17        1.39                 Sombrio
# 407    296.15        6.70                   Dalby
# 421    297.80        8.99           Cockburn Town
# 425    298.15        2.10              Vila Velha
# 430    297.71       10.96                CIDREIRA
# 436    298.15        2.05                 Griffin
# 438    297.87        8.40                Yaguajay
# 461    297.15        4.10
# 468    297.94        4.62
# 471    298.35        1.45                  N'Délé
# 473    299.99        3.61                 Polillo
# 474    295.05        2.88                 Hiriyur
# 476    298.15        2.10            Saint-Joseph
# 482    299.15        0.24                  Najran
# 494    299.15        8.20  Sabanilla Montecarmelo
# 496    297.15        5.70                   Praia
# 508    298.31        3.69                 Pototan
# 519    297.15        4.10              Saint-Paul
# 524    297.04        1.34
# 530    299.87        1.50                   Beira
# 536    298.43        7.83                 La Cruz
# 553    298.15        1.00           Central Flacq
# 555    296.94        4.02                   Birao
# 558    297.59        1.50                   Houma
# 559    298.15        2.60                Gonzales
# 568    299.70        2.39                   Dawei
# 580    299.01        0.60                 Palauig

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map

markers = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(markers)
# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
